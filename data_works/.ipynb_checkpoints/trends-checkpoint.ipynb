# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (12,6)

df = pd.read_csv("../dataset_final_bartek.csv")
df.head()
# Out:
#    Year  Country  Disease  Cases  Population  Incidence  \
# 0  1999  Austria  Measles   22.0   7982461.0       0.28
# 1  2000  Austria  Measles    0.0   8002186.0       0.00
# 2  2001  Austria  Measles    0.0   8020946.0       0.00
# 3  2002  Austria  Measles    0.0   8063640.0       0.00
# 4  2003  Austria  Measles   99.0   8100273.0       1.22
#
#    Pop_Structure_0_14_Pct  Vaccination_Coverage_Pct
# 0                    15.0                      93.0
# 1                    15.0                      93.0
# 2                    15.0                      93.0
# 3                    15.0                      93.0
# 4                    15.0                      93.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3043 entries, 0 to 3042
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Year                      3043 non-null   int64
#  1   Country                   3043 non-null   object
#  2   Disease                   3043 non-null   object
#  3   Cases                     2919 non-null   float64
#  4   Population                3043 non-null   float64
#  5   Incidence                 2919 non-null   float64
#  6   Pop_Structure_0_14_Pct    3043 non-null   float64
#  7   Vaccination_Coverage_Pct  3043 non-null   float64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 190.3+ KB

# %%
df.describe()
# Out:
#               Year         Cases    Population    Incidence  \
# count  3043.000000   2919.000000  3.043000e+03  2919.000000
# mean   2011.258955   1637.115108  1.652735e+07    12.229955
# std       7.774390   3661.718597  2.221130e+07    21.221005
# min    1995.000000      0.000000  3.062900e+04     0.000000
# 25%    2005.000000     15.000000  2.410018e+06     0.320000
# 50%    2012.000000    271.000000  7.518002e+06     5.190000
# 75%    2018.000000   1338.500000  1.635799e+07    13.610000
# max    2025.000000  55399.000000  8.345604e+07   296.490000
#
#        Pop_Structure_0_14_Pct  Vaccination_Coverage_Pct
# count             3043.000000               3043.000000
# mean                15.237496                 93.390404
# std                  1.041277                  1.501938
# min                 12.700000                 90.000000
# 25%                 15.000000                 93.000000
# 50%                 15.000000                 93.000000
# 75%                 15.000000                 93.000000
# max                 17.800000                 98.000000

# %%
df.isna().sum()
# Out:
# Year                          0
# Country                       0
# Disease                       0
# Cases                       124
# Population                    0
# Incidence                   124
# Pop_Structure_0_14_Pct        0
# Vaccination_Coverage_Pct      0
# dtype: int64

# %%
sns.boxplot(data=df, x="Incidence")
plt.title("Rozkład zachorowań (Incidence)")
plt.show()

# %%
plt.figure(figsize=(14,6))
sns.boxplot(data=df, x="Country", y="Incidence")
plt.xticks(rotation=90)
plt.title("Zachorowania – porównanie krajów")
plt.show()

# %%
country = "Austria"
df_country = df[df["Country"] == country]

sns.lineplot(data=df_country, x="Year", y="Incidence")
plt.title(f"Trend zachorowań – {country}")
plt.show()

# %%
g = sns.FacetGrid(df, col="Country", col_wrap=4, height=3)
g.map(sns.lineplot, "Year", "Incidence")
g.set_titles("{col_name}")
plt.show()

# %%
sns.lineplot(data=df, x="Year", y="Incidence", estimator="mean")
plt.title("Średni trend zachorowań (wszystkie kraje)")
plt.show()

# %%
country_avg = df.groupby("Country")["Incidence"].mean().sort_values(ascending=False)

country_avg.plot(kind="bar")
plt.title("Średnia zachorowalność wg kraju")
plt.ylabel("Incidence")
plt.show()

# %%
pivot = df.pivot_table(
    values="Incidence",
    index="Country",
    columns="Year",
    aggfunc="mean"
)

sns.heatmap(pivot, cmap="Reds")
plt.title("Heatmapa zachorowań (Country x Year)")
plt.show()

# %%
corr = df[[
    "Incidence",
    "Vaccination_Coverage_Pct",
    "Pop_Structure_0_14_Pct"
]].corr()

sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Korelacje zmiennych")
plt.show()

# %%
plt.figure(figsize=(12,6))

ax = sns.scatterplot(
    data=df,
    x="Vaccination_Coverage_Pct",
    y="Incidence",
    hue="Country"
)

plt.title("Szczepienia vs zachorowalność")
plt.xlabel("Poziom wyszczepienia (%)")
plt.ylabel("Zachorowalność")

# legenda pod wykresem
plt.legend(
    title="Kraj",
    bbox_to_anchor=(0.5, -0.25),
    loc="upper center",
    ncol=4,
    frameon=False
)

plt.tight_layout()
plt.show()
